# %%
import os
import sys
import numpy as np
import pandas as pd
import networkx as nx
pd.options.display.float_format = "{:,.2f}".format

# %%
net= pd.read_csv('data/SiouxFalls_net.tntp', skiprows=8, sep='\t').drop(['~', ';'], axis =1)
net['edge']=net.index+1

# %%
flow=pd.read_csv('data/SiouxFalls_flow.tntp',sep='\t').drop(['From ', 'To '],axis=1)

# %%
flow.rename(columns={"Volume ": "flow", "Cost ": "cost"},inplace=True)

# %%
node=pd.read_csv('data/SiouxFalls_node.tntp',sep='\t').drop([';'], axis=1)

# %%
node_xy=pd.read_csv('data/SiouxFalls_node_xy.tntp',sep='\t')

# %%
node_xy
# Out:
#     Node       X       Y
# 0      1   50000  510000
# 1      2  320000  510000
# 2      3   50000  440000
# 3      4  130000  440000
# 4      5  220000  440000
# 5      6  320000  440000
# 6      7  420000  380000
# 7      8  320000  380000
# 8      9  220000  380000
# 9     10  220000  320000
# 10    11  130000  320000
# 11    12   50000  320000
# 12    13   50000   50000
# 13    14  130000  190000
# 14    15  220000  190000
# 15    16  320000  320000
# 16    17  320000  260000
# 17    18  420000  320000
# 18    19  320000  190000
# 19    20  320000   50000
# 20    21  220000   50000
# 21    22  220000  130000
# 22    23  130000  130000
# 23    24  130000   50000

# %%
final=pd.concat([net,flow], axis=1)

# %%
final
# Out:
#     init_node  term_node  capacity  length  free_flow_time    b  power  speed  \
# 0           1          2 25,900.20       6               6 0.15      4      0
# 1           1          3 23,403.47       4               4 0.15      4      0
# 2           2          1 25,900.20       6               6 0.15      4      0
# 3           2          6  4,958.18       5               5 0.15      4      0
# 4           3          1 23,403.47       4               4 0.15      4      0
# ..        ...        ...       ...     ...             ...  ...    ...    ...
# 71         23         22  5,000.00       4               4 0.15      4      0
# 72         23         24  5,078.51       2               2 0.15      4      0
# 73         24         13  5,091.26       4               4 0.15      4      0
# 74         24         21  4,885.36       3               3 0.15      4      0
# 75         24         23  5,078.51       2               2 0.15      4      0
#
# ...

# %%
node
# Out:
#     Node      X     Y
# 0      1 -96.77 43.61
# 1      2 -96.71 43.61
# 2      3 -96.77 43.57
# 3      4 -96.75 43.56
# 4      5 -96.73 43.56
# 5      6 -96.71 43.59
# 6      7 -96.69 43.56
# 7      8 -96.71 43.56
# 8      9 -96.73 43.55
# 9     10 -96.73 43.55
# 10    11 -96.75 43.54
# 11    12 -96.78 43.54
# 12    13 -96.79 43.49
# 13    14 -96.75 43.53
# 14    15 -96.73 43.53
# 15    16 -96.71 43.55
# 16    17 -96.71 43.54
# 17    18 -96.69 43.55
# 18    19 -96.71 43.53
# 19    20 -96.71 43.52
# 20    21 -96.73 43.51
# 21    22 -96.73 43.51
# 22    23 -96.75 43.51
# 23    24 -96.75 43.50

# %%
pos=dict([(i,(a,b)) for i, a,b in zip(node.Node, node.X,node.Y)])

# %%
pos_xy=dict([(i,(a,b)) for i, a,b in zip(node_xy.Node, node_xy.X,node_xy.Y)])

# %%
pos_xy
# Out:
# {1: (50000, 510000),
#  2: (320000, 510000),
#  3: (50000, 440000),
#  4: (130000, 440000),
#  5: (220000, 440000),
#  6: (320000, 440000),
#  7: (420000, 380000),
#  8: (320000, 380000),
#  9: (220000, 380000),
#  10: (220000, 320000),
#  11: (130000, 320000),
#  12: (50000, 320000),
#  13: (50000, 50000),
#  14: (130000, 190000),
#  15: (220000, 190000),
#  16: (320000, 320000),
#  17: (320000, 260000),
#  18: (420000, 320000),
#  19: (320000, 190000),
#  20: (320000, 50000),
#  21: (220000, 50000),
#  22: (220000, 130000),
#  23: (130000, 130000),
#  24: (130000, 50000)}

# %%
final=pd.concat([net,flow], axis=1)

# %%
final.columns
# Out:
# Index(['init_node', 'term_node', 'capacity', 'length', 'free_flow_time', 'b',
#        'power', 'speed', 'toll', 'link_type', 'edge', 'From ', 'To ',
#        'Volume ', 'Cost '],
#       dtype='object')

# %%
for n, p in pos_xy.items():
    G.nodes[n]['pos_xy'] = p
    
#nx.draw(X, pos)
#plt.show()

# %%
nx.draw(G, po_xy,with_labels = True)
#plt.show()

# %%
nx.draw(G, pos_xy,with_labels = True)
#plt.show()

# %%
edge_labels = nx.get_edge_attributes(G,'edge')

# %%
import pygraphviz as pgv
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_161/3415047245.py in <module>
# ----> 1 import pygraphviz as pgv
#
# ModuleNotFoundError: No module named 'pygraphviz'

# %%
#!sudo apt-get install graphviz graphviz-dev
# !pip install pygraphviz
# Out:
# ...
#   Using cached pygraphviz-1.7.zip (118 kB)
# ...
#   ERROR: Command errored out with exit status 1:
#    command: /usr/bin/python3 -u -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'/tmp/pip-install-roxo0_xl/pygraphviz_f9b642705aa34f03a771678ffe1d6833/setup.py'"'"'; __file__='"'"'/tmp/pip-install-roxo0_xl/pygraphviz_f9b642705aa34f03a771678ffe1d6833/setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-i6bst73c
#        cwd: /tmp/pip-install-roxo0_xl/pygraphviz_f9b642705aa34f03a771678ffe1d6833/
#   Complete output (54 lines):
#   running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.linux-x86_64-3.8
#   creating build/lib.linux-x86_64-3.8/pygraphviz
# ...

# %%
# !pip upgrade pip
# Out:
# ERROR: unknown command "upgrade"

# %%
nx.drawing.nx_pydot.write_dot(p_graph, 'networkx_graph.png')
gv.render('dot', 'png', 'networkx_graph.png')

# %%
from networkx.drawing import nx_pydot
from graphviz import Source

# %%
G.nodes.data()
# Out:
# NodeDataView({1: {}, 2: {}, 3: {}, 6: {}, 4: {}, 12: {}, 5: {}, 11: {}, 9: {}, 8: {}, 7: {}, 18: {}, 16: {}, 10: {}, 15: {}, 17: {}, 14: {}, 13: {}, 24: {}, 23: {}, 19: {}, 22: {}, 20: {}, 21: {}})

# %%
G = nx.from_pandas_edgelist(final, 'init_node', 'term_node', ['capacity','length','free_flow_time','b','power','speed','toll','link_type','edge','flow','cost'],create_using=nx.MultiDiGraph())

# %%
nx.draw(G,with_labels = True)

# %%
type(G)
# Out:
# networkx.classes.multigraph.MultiGraph

# %%
nx.set_node_attributes(G,node_att)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_161/2870735482.py in <module>
# ----> 1 nx.set_node_attributes(G,node_att)
#
# /usr/local/lib/python3.8/dist-packages/networkx/classes/function.py in set_node_attributes(G, values, name)
#     687         for n, d in values.items():
#     688             try:
# --> 689                 G.nodes[n].update(d)
#     690             except KeyError:
#     691                 pass
#
# TypeError: cannot convert dictionary update sequence element #0 to a sequence

# %%
G = nx.from_pandas_edgelist(df, 0, "b", ["weight", "cost"])

# %%
type(G)
# Out:
# networkx.classes.graph.Graph
